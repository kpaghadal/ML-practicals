# %% [markdown]
# Tutorial 4: Implement Decision tree and Naive bayes

# %% [markdown]
# Exercise 1: Decision Tree

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %%
user = pd.read_csv("data/users.csv")

# %%
user["Age"].min()
# Out:
# np.int64(1)

# %%
user["Age"].max()
# Out:
# np.int64(64)

# %%
user["EstimatedSalary"].min()
# Out:
# np.int64(15000)

# %%
user["EstimatedSalary"].max()
# Out:
# np.int64(150000)

# %% [markdown]
# setting the predictor and target

# %%
X = user.columns.drop("Purchased")
Y = user ["Purchased"]

# %%
user_encoded = pd.get_dummies(user[X]).astype=(int)

# %%
# #Impothe required function 
# from sklearn.model_selection import train_test_split    
# #splitting data info train and test datasets
# X_train, X_test, Y_train, Y_test = train_test_split(user_encoded, Y, test_size=0.15, random_state=0)
# #printing the shape of the resulting datasets
# print("Shape of X_train and Y_train are:",X_train.shape, "and" , Y_train.shape, "respectively")
# print("Shape of X_test and Y_test are:",X_test.shape, "and" , Y_test.shape, "respectively")
# Import libraries


# Encode Gender column
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])

# Define features and target
user_encoded = df[['Gender','Age','EstimatedSalary']]
Y = df['Purchased']

# Convert to numpy arrays
user_encoded = np.array(user_encoded)
Y = np.array(Y)

# Split dataset
X_train, X_test, Y_train, Y_test = train_test_split(
    user_encoded, Y, test_size=0.15, random_state=0
)

# %%
df
# Out:
#      User ID  Gender  Age  EstimatedSalary  Purchased
# 0   15624510    Male   12            19000          0
# 1   15810944    Male   11            20000          0
# 2   15668575  Female    1            43000          0
# 3   15603246  Female   27            57000          0
# 4   15804002    Male   10            76000          0
# ..       ...     ...  ...              ...        ...
# 94  15786993  Female   45            83000          0
# 95  15709441  Female   35            44000          0
# 96  15710257  Female    4            25000          0
# 97  15582492    Male    5           123000          1
# 98  15575694    Male   35            73000          0
#
# [99 rows x 5 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion="gini", random_state=1)
model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# %%
pip install graphviz
# Out:
# ...
#    ---------------------------------------- 0.0/47.3 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/47.3 kB ? eta -:--:--
#    ----------------- ---------------------- 20.5/47.3 kB 330.3 kB/s eta 0:00:01
#    ------------------------- -------------- 30.7/47.3 kB 262.6 kB/s eta 0:00:01
#    ---------------------------------- ----- 41.0/47.3 kB 281.8 kB/s eta 0:00:01
#    ---------------------------------- ----- 41.0/47.3 kB 281.8 kB/s eta 0:00:01
#    ---------------------------------------- 47.3/47.3 kB 158.4 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn import tree
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
tree.plot_tree(model, feature_names=['Gender','Age','EstimatedSalary'], filled=True)
plt.show()

# %%
train_accuracy = model.score(X_train, Y_train)
print("accuracy of the training data =", train_accuracy)


test_accuracy = model.score(X_test, Y_test)
print("accuracy of the test data =", test_accuracy)j
# Out:
# accuracy of the training data = 0.9880952380952381
# accuracy of the test data = 0.9333333333333333
